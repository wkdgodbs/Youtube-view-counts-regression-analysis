# %% [markdown]
# # 유투브 조회수와 연관된 변수들간의 회귀분석 및 예측모델
# #### Main columns to look at:
# #### comment_count,likes,dislikes,subscriber (and some combination of the other features)

# %% [markdown]
# ##### 먼저, 데이터에 대한 이해하기
# - 각 column 에 대한 이해
# - summary values and features 이해
# - missing data

# %%
#관련된 모듈 불러오기
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as plt

# %%
#데이터로드 (5/16 일 scrapping한 데이터)
youtube = pd.read_csv("output/20.16.05_KR_videos.csv",encoding = 'UTF-8')
youtube.head()
# Out:
#       video_id                                              title  \
# 0  sEoF2oIcjBs         [놀면뭐하니? 예고] 놀면뭐하니를 찾아온 댄스 레전드 비! (feat. 깡)
# 1  iK3kwZY6epY  자간을 물리치는 가은｜10화 하이라이트｜신비아파트 고스트볼 더블X : 6개의 예언｜...
# 2  atD5O2XCbLw     죄수와 검사Ⅱ(한명숙) ③ 나는 검찰의 개였다 한만호 비망록 단독 입수 - 뉴스타파
# 3  ITROwFtwAxQ                  김어준의 다스뵈이다 115회 윤미향, 이태원 그리고 조국재판
# 4  O9e2oZXEKW8  아이유가 포스트말론 맞팔한 이유? 본인등판에서 확인하기🙋 | IU_ eight(에잇...
#
#             publishedAt                 channelId  \
# 0  2020-05-14T17:08:48Z  UCx6jsZ02B4K3SECUrkgPyzg
# 1  2020-05-15T01:00:10Z  UCoHsxU1eDWHom6D7Fce6kLA
# 2  2020-05-14T02:12:08Z  UCeFUGS2VCOb6DO3BiUgvwNA
# 3  2020-05-15T13:00:14Z  UCxvU6bRtYhNLvZleAIGa-FQ
# 4  2020-05-12T10:00:11Z  UCqq-ovGE01ErlXakPihhKDA
#
#                   channelTitle  categoryId trending_date  \
# 0                      놀면 뭐하니?          24      20.16.05
# 1                  신비아파트 공식 채널           1      20.16.05
# 2                     newstapa          25      20.16.05
# ...

# %%
youtube.columns
# Out:
# Index(['video_id', 'title', 'publishedAt', 'channelId', 'channelTitle',
#        'categoryId', 'trending_date', 'tags', 'view_count', 'subscriber_count',
#        'comment_count', 'likes', 'dislikes', 'comment_count.1',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'description'],
#       dtype='object')

# %% [markdown]
# - video_id : unique id per video
# - last_trending_date :
# - publish_date :
# - publish_hour :
# - category_id :
# - channel_title :
# - views :
# - likes :
# - dislikes :
# - comment_count :
# - comments_disabled :
# - ratings_disabled :
# - tag_appeared_in_title_count :
# - tag_appeared_in_title :
# - title :
# - tags :
# - description :
# - trend_day_count :
# - trend.publish.diff :
# - trend_tag_highest :
# - trend_tag_total :
# - tags_count :
# - subscriber :

# %%
youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 18 columns):
# video_id             200 non-null object
# title                200 non-null object
# publishedAt          200 non-null object
# channelId            200 non-null object
# channelTitle         200 non-null object
# categoryId           200 non-null int64
# trending_date        200 non-null object
# tags                 200 non-null object
# view_count           200 non-null int64
# subscriber_count     200 non-null int64
# comment_count        200 non-null int64
# likes                200 non-null int64
# dislikes             200 non-null int64
# comment_count.1      200 non-null int64
# thumbnail_link       200 non-null object
# comments_disabled    200 non-null bool
# ratings_disabled     200 non-null bool
# description          197 non-null object
# dtypes: bool(2), int64(7), object(9)
# memory usage: 25.5+ KB

# %%
#summary statistics 
youtube.describe()
# Out:
#        categoryId    view_count  subscriber_count  comment_count  \
# count  200.000000  2.000000e+02             200.0     200.000000
# mean    19.795000  6.177974e+05               0.0    3068.030000
# std      7.210613  1.191369e+06               0.0    6768.436703
# min      1.000000  1.773200e+04               0.0       0.000000
# 25%     15.000000  1.247688e+05               0.0     418.250000
# 50%     24.000000  3.152350e+05               0.0    1009.500000
# 75%     24.000000  6.329788e+05               0.0    2858.000000
# max     29.000000  1.000399e+07               0.0   60005.000000
#
#                likes     dislikes  comment_count.1
# count     200.000000   200.000000       200.000000
# mean    30778.645000   400.085000      3068.030000
# std     82426.695436   903.644323      6768.436703
# min       268.000000     5.000000         0.000000
# 25%      3155.750000    70.000000       418.250000
# 50%      8509.000000   141.500000      1009.500000
# ...

# %%
#missing value
youtube.isnull().sum()
# Out:
# video_id             0
# title                0
# publishedAt          0
# channelId            0
# channelTitle         0
# categoryId           0
# trending_date        0
# tags                 0
# view_count           0
# subscriber_count     0
# comment_count        0
# likes                0
# dislikes             0
# comment_count.1      0
# thumbnail_link       0
# comments_disabled    0
# ratings_disabled     0
# description          3
# dtype: int64
