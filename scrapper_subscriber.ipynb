# %%
import requests, sys, time, os, argparse 
from bs4 import BeautifulSoup as bs 
import pandas as pd

Data = pd.read_csv("output/20.16.05_KR_videos.csv",encoding = 'UTF-8')

# %%
def get_subs(channelId):    
    request_url = "https://www.youtube.com/channel/"+channel
    request = requests.get(request_url)    
    soup = bs(request.text, "html.parser")
    channels = soup.findAll("span", {"class": "yt-subscription-button-subscriber-count-branded-horizontal subscribed yt-uix-tooltip"})
    for subscribers in channels:
        return subscribers.get_text().replace("만","")

subslist=[]
for channel in Data["channelId"]:
    subslist.append(get_subs(channel))
print(subslist)
# Out:
# ['55.7', '38.4', '53.1', None, '8.07', '84', '86.5', '174', '77.2', '227', '51.5', '89', '47.1', '108', '22.2', '25.3', '116', '43.5', '5.67', '1530', '14.7', '85.5', '319', '35.4', '120', '23.9', '132', '723', '163', '379', '19.6', '237', '96.7', '3.32', '15.2', '81.6', '535', '120', '14.4', '318', None, '1560', '187', '12', '18.5', '123', '16.4', None, '401', '370', None, '47.1', '689', '11.3', '29.3', None, '63.4', None, None, '83.2', '66.6', '48', '85.5', '366', '55.4', '700', '10.9', '116', '14.5', '28.5', '38.4', '6.28', '80.7', '85.1', '110', None, '3.32', '22.2', '10.4', '384', '55.3', '84.2', '50.8', '538', '65.5', '215', '229', '187', '41.6', '41.6', '63.4', '148', '101', '123', '85.5', '29', '89', None, '29.1', '4.22', '89', '24.4', None, '55.3', '5.47', '64.2', '1560', '9.13', '73.3', '170', '10.5', '41.6', '55.5', '24.3', '123', '59', '319', '44.4', '9.69', '84.5', '104', '53.1', '29.1', '125', '61.9', '21.2', '25.5', '25.4', '28.1', '76.3', '401', None, '31.4', '525', '
# ...

# %%
import numpy as np
subscriber_count = pd.DataFrame(subslist, dtype=np.float16, columns=['subscriber_count'])
Data["subscriber_count"] = subscriber_count
Data.index = np.arange(1,len(subscriber_count)+1)

# %%
Data
# Out:
#         video_id                                              title  \
# 1    sEoF2oIcjBs         [놀면뭐하니? 예고] 놀면뭐하니를 찾아온 댄스 레전드 비! (feat. 깡)
# 2    iK3kwZY6epY  자간을 물리치는 가은｜10화 하이라이트｜신비아파트 고스트볼 더블X : 6개의 예언｜...
# 3    atD5O2XCbLw     죄수와 검사Ⅱ(한명숙) ③ 나는 검찰의 개였다 한만호 비망록 단독 입수 - 뉴스타파
# 4    O9e2oZXEKW8  아이유가 포스트말론 맞팔한 이유? 본인등판에서 확인하기🙋 | IU_ eight(에잇...
# 5    mB9HK4-g27Q  독일 공영방송 도이체벨레(DW) 강경화 외교부 장관 인터뷰 [한글자막 CC /ENG...
# ..           ...                                                ...
# 196  O9bl3tdhN0E                         [불후의명곡] 요요미 YOYOMI 출연 컷 모음
# 197  MVE-QnCMLCE       [TJ노래방] 에잇 - IU(Prod,Feat.SUGA) / TJ Karaoke
# 198  m74oG2D_ezo  끝까지 참아주던 한국이 결국 일본에 최후통첩 해버린 상황, 일본, 한국이 보내줄것 ...
# 199  bUPdvtsqd2w       귀신의 장난일까? 사건파일138. 귀신의 소행?! | 공포 공소시효 [밍꼬발랄]
# 200  CyEydeum3PU                                           다시 시작할까?
#
#               publishedAt                 channelId  \
# 1    2020-05-14T17:08:48Z  UCx6jsZ02B4K3SECUrkgPyzg
# ...

# %%
Data.to_csv("output/20.16.05_KR_videos_subscriber.csv")
